# %%
import sys,os
import numpy as np, pandas as pd
import dill
from sklearn import datasets
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.optimizers import SGD
from keras.layers.advanced_activations import LeakyReLU as lrelu, PReLU
import tensorflow as tf

# %%
filename = 'mnist.pickle'
if os.path.exists(filename):
    with open(filename, 'rb') as f:
        mnist = dill.load(f)
else: 
    mnist = datasets.fetch_mldata('MNIST original', data_home='.')
    with open(filename, 'wb') as g:
        dill.dump(mnist, g)

# %%
n = len(mnist.data)
N = 10000 
indices = np.random.permutation(range(n))[:N]
X = mnist.data[indices]
y = mnist.target[indices]
Y = np.eye(10)[y.astype(int)]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=0.8)
# Out:
# /Users/nagoyan/anaconda/envs/p3/lib/python3.5/site-packages/sklearn/model_selection/_split.py:2010: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
n_in = len(X[0])
n_hidden=200
n_out = len(Y[0])
print(n_in, n_hidden, n_out)
# Out:
# 784 200 10

# %%
funcs = ['tanh', 'relu', 'softmax', 'sigmoid']
activation_func='relu'
alpha = 0.01 # parameter for LeakyReLU

model = Sequential()

model.add(Dense(n_hidden, input_dim=n_in))
model.add(Activation(PReLU()))

model.add(Dense(n_hidden))
model.add(Activation(PReLU()))

model.add(Dense(n_hidden))
model.add(Activation(PReLU()))

model.add(Dense(n_hidden))
model.add(Activation(PReLU()))

model.add(Dense(n_out))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', optimizer=SGD(lr=0.01), metrics=['accuracy'])
# Out:
# /Users/nagoyan/anaconda/envs/p3/lib/python3.5/site-packages/keras/activations.py:103: UserWarning: Do not pass a layer instance (such as PReLU) as the activation argument of another layer. Instead, advanced activation layers should be used just like any other layer in a model.
#   ).format(identifier=identifier.__class__.__name__))

# %%
epochs = 100
batch_size = 100

model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size)
# Out:
# Epoch 1/100
# 8000/8000 [==============================] - 1s 182us/step - loss: 14.5573 - acc: 0.0959
# Epoch 2/100
# 8000/8000 [==============================] - 1s 115us/step - loss: 14.5587 - acc: 0.0967
# Epoch 3/100
# 8000/8000 [==============================] - 1s 122us/step - loss: 14.5587 - acc: 0.0967
# Epoch 4/100
# 8000/8000 [==============================] - 1s 123us/step - loss: 14.5587 - acc: 0.0967
# Epoch 5/100
# 8000/8000 [==============================] - 1s 125us/step - loss: 14.5587 - acc: 0.0968
# Epoch 6/100
# 8000/8000 [==============================] - 1s 134us/step - loss: 14.5587 - acc: 0.0968
# Epoch 7/100
# 8000/8000 [==============================] - 1s 138us/step - loss: 14.5587 - acc: 0.0967
# Epoch 8/100
# 8000/8000 [==============================] - 1s 147us/step - loss: 14.5587 - acc: 0.0968
# Epoch 9/100
# 8000/8000 [==============================] - 1s 143us/step - loss: 14.5587 - acc: 0.0968
# Epoch 10/100
# 8000/8000 [==============================] - 1s 153us/step - loss: 14.5587 - acc: 0.0967
# Epoch 11/100
# 8000/8000 [==============================] - 1s 153us/step - loss: 14.5587 - acc: 0.0968
# Epoch 12/100
# 8000/8000 [==============================] - 1s 148us/step - loss: 14.5587 - acc: 0.0967
# Epoch 13/100
# 8000/8000 [==============================] - 1s 150us/step - loss: 14.5587 - acc: 0.0968
# Epoch 14/100
# 8000/8000 [==============================] - 1s 162us/step - loss: 14.5587 - acc: 0.0968
# Epoch 15/100
# 8000/8000 [==============================] - 1s 164us/step - loss: 14.5587 - acc: 0.0967
# Epoch 16/100
# 8000/8000 [==============================] - 1s 161us/step - loss: 14.5587 - acc: 0.0968
# Epoch 17/100
# 8000/8000 [==============================] - 1s 164us/step - loss: 14.5587 - acc: 0.0968
# Epoch 18/100
# 8000/8000 [==============================] - 1s 132us/step - loss: 14.5587 - acc: 0.0967
# Epoch 19/100
# 8000/8000 [==============================] - 1s 163us/step - loss: 14.5587 - acc: 0.0968
# Epoch 20/100
# 8000/8000 [==============================] - 1s 159us/step - loss: 14.5587 - acc: 0.0967
# Epoch 21/100
# 8000/8000 [==============================] - 1s 165us/step - loss: 14.5587 - acc: 0.0967
# Epoch 22/100
# 8000/8000 [==============================] - 1s 168us/step - loss: 14.5587 - acc: 0.0967
# Epoch 23/100
# 8000/8000 [==============================] - 1s 163us/step - loss: 14.5587 - acc: 0.0967
# Epoch 24/100
# 8000/8000 [==============================] - 1s 162us/step - loss: 14.5587 - acc: 0.0968
# Epoch 25/100
# 8000/8000 [==============================] - 1s 162us/step - loss: 14.5587 - acc: 0.0968
# Epoch 26/100
# 8000/8000 [==============================] - 1s 167us/step - loss: 14.5587 - acc: 0.0967
# Epoch 27/100
# 8000/8000 [==============================] - 1s 159us/step - loss: 14.5587 - acc: 0.0967
# Epoch 28/100
# 8000/8000 [==============================] - 1s 160us/step - loss: 14.5587 - acc: 0.0967
# Epoch 29/100
# 8000/8000 [==============================] - 1s 128us/step - loss: 14.5587 - acc: 0.0967
# Epoch 30/100
# 8000/8000 [==============================] - 1s 140us/step - loss: 14.5587 - acc: 0.0967
# Epoch 31/100
# 8000/8000 [==============================] - 1s 133us/step - loss: 14.5587 - acc: 0.0968
# Epoch 32/100
# 8000/8000 [==============================] - 1s 161us/step - loss: 14.5587 - acc: 0.0968
# Epoch 33/100
# 8000/8000 [==============================] - 1s 154us/step - loss: 14.5587 - acc: 0.0968
# Epoch 34/100
# 8000/8000 [==============================] - 1s 169us/step - loss: 14.5587 - acc: 0.0967
# Epoch 35/100
# 8000/8000 [==============================] - 1s 165us/step - loss: 14.5587 - acc: 0.0967
# Epoch 36/100
# 8000/8000 [==============================] - 1s 130us/step - loss: 14.5587 - acc: 0.0967
# Epoch 37/100
# 8000/8000 [==============================] - 1s 161us/step - loss: 14.5587 - acc: 0.0968
# Epoch 38/100
# 8000/8000 [==============================] - 1s 150us/step - loss: 14.5587 - acc: 0.0968
# Epoch 39/100
# 8000/8000 [==============================] - 1s 140us/step - loss: 14.5587 - acc: 0.0967
# Epoch 40/100
# 8000/8000 [==============================] - 1s 155us/step - loss: 14.5587 - acc: 0.0968
# Epoch 41/100
# 8000/8000 [==============================] - 1s 161us/step - loss: 14.5587 - acc: 0.0967
# Epoch 42/100
# 8000/8000 [==============================] - 1s 159us/step - loss: 14.5587 - acc: 0.0967
# Epoch 43/100
#  - ETA: 0s - loss: 14.6444 - acc: 0.0914
# Epoch 44/100
#  - ETA: 0s - loss: 14.5614 - acc: 0.0966
# Epoch 45/100
# 8000/8000 [==============================] - 1s 149us/step - loss: 14.5587 - acc: 0.0968
# Epoch 46/100
# 8000/8000 [==============================] - 1s 160us/step - loss: 14.5587 - acc: 0.0967
# Epoch 47/100
# 8000/8000 [==============================] - 1s 163us/step - loss: 14.5587 - acc: 0.0968
# Epoch 48/100
# 8000/8000 [==============================] - 1s 162us/step - loss: 14.5587 - acc: 0.0967
# Epoch 49/100
# 8000/8000 [==============================] - 1s 158us/step - loss: 14.5587 - acc: 0.0967
# Epoch 50/100
# 8000/8000 [==============================] - 1s 167us/step - loss: 14.5587 - acc: 0.0968
# Epoch 51/100
# 8000/8000 [==============================] - 1s 166us/step - loss: 14.5587 - acc: 0.0968
# Epoch 52/100
# 8000/8000 [==============================] - 1s 159us/step - loss: 14.5587 - acc: 0.0967
# Epoch 53/100
# 8000/8000 [==============================] - 1s 158us/step - loss: 14.5587 - acc: 0.0967
# Epoch 54/100
# 8000/8000 [==============================] - 1s 170us/step - loss: 14.5587 - acc: 0.0967
# Epoch 55/100
# 8000/8000 [==============================] - 1s 165us/step - loss: 14.5587 - acc: 0.0967
# Epoch 56/100
# 8000/8000 [==============================] - 1s 159us/step - loss: 14.5587 - acc: 0.0967
# Epoch 57/100
#  - ETA: 1s - loss: 14.4660 - acc: 0.1025
# Epoch 58/100
# 8000/8000 [==============================] - 1s 172us/step - loss: 14.5587 - acc: 0.0967
# Epoch 59/100
# 8000/8000 [==============================] - 1s 165us/step - loss: 14.5587 - acc: 0.0968
# Epoch 60/100
#  - 1s 164us/step - loss: 14.5587 - acc: 0.0967
# Epoch 61/100
# 8000/8000 [==============================] - 1s 164us/step - loss: 14.5587 - acc: 0.0967
# Epoch 62/100
# 8000/8000 [==============================] - 1s 157us/step - loss: 14.5587 - acc: 0.0967
# Epoch 63/100
# 8000/8000 [==============================] - 1s 164us/step - loss: 14.5587 - acc: 0.0968
# Epoch 64/100
# 8000/8000 [==============================] - 1s 139us/step - loss: 14.5587 - acc: 0.0967
# Epoch 65/100
# 8000/8000 [==============================] - 1s 161us/step - loss: 14.5587 - acc: 0.0967
# Epoch 66/100
# 8000/8000 [==============================] - 1s 157us/step - loss: 14.5587 - acc: 0.0967
# Epoch 67/100
# 8000/8000 [==============================] - 1s 163us/step - loss: 14.5587 - acc: 0.0968
# Epoch 68/100
# 8000/8000 [==============================] - 1s 158us/step - loss: 14.5587 - acc: 0.0967
# Epoch 69/100
# 8000/8000 [==============================] - 1s 152us/step - loss: 14.5587 - acc: 0.0968
# Epoch 70/100
# 8000/8000 [==============================] - 1s 155us/step - loss: 14.5587 - acc: 0.0967
# Epoch 71/100
# 8000/8000 [==============================] - 1s 150us/step - loss: 14.5587 - acc: 0.0967
# Epoch 72/100
# 8000/8000 [==============================] - 1s 153us/step - loss: 14.5587 - acc: 0.0968
# Epoch 73/100
# 8000/8000 [==============================] - 1s 153us/step - loss: 14.5587 - acc: 0.0968
# Epoch 74/100
# 8000/8000 [==============================] - 1s 163us/step - loss: 14.5587 - acc: 0.0967
# Epoch 75/100
# 8000/8000 [==============================] - 1s 159us/step - loss: 14.5587 - acc: 0.0967
# Epoch 76/100
# 8000/8000 [==============================] - 1s 160us/step - loss: 14.5587 - acc: 0.0967
# Epoch 77/100
# 8000/8000 [==============================] - 1s 153us/step - loss: 14.5587 - acc: 0.0968
# Epoch 78/100
# 8000/8000 [==============================] - 1s 159us/step - loss: 14.5587 - acc: 0.0968
# Epoch 79/100
# 8000/8000 [==============================] - 1s 161us/step - loss: 14.5587 - acc: 0.0968
# Epoch 80/100
# 8000/8000 [==============================] - 1s 166us/step - loss: 14.5587 - acc: 0.0967
# Epoch 81/100
# 8000/8000 [==============================] - 1s 165us/step - loss: 14.5587 - acc: 0.0967
# Epoch 82/100
# 8000/8000 [==============================] - 1s 161us/step - loss: 14.5587 - acc: 0.0967
# Epoch 83/100
# 8000/8000 [==============================] - 1s 161us/step - loss: 14.5587 - acc: 0.0967
# Epoch 84/100
# 8000/8000 [==============================] - 1s 158us/step - loss: 14.5587 - acc: 0.0967
# Epoch 85/100
# 8000/8000 [==============================] - 1s 156us/step - loss: 14.5587 - acc: 0.0968
# Epoch 86/100
# 8000/8000 [==============================] - 1s 158us/step - loss: 14.5587 - acc: 0.0968
# Epoch 87/100
# 8000/8000 [==============================] - 1s 153us/step - loss: 14.5587 - acc: 0.0968
# Epoch 88/100
# 8000/8000 [==============================] - 1s 158us/step - loss: 14.5587 - acc: 0.0967
# Epoch 89/100
#  - 1s 163us/step - loss: 14.5587 - acc: 0.0968
# Epoch 90/100
# 8000/8000 [==============================] - 1s 158us/step - loss: 14.5587 - acc: 0.0967
# Epoch 91/100
# 8000/8000 [==============================] - 1s 162us/step - loss: 14.5587 - acc: 0.0967
# Epoch 92/100
#  - ETA: 1s - loss: 14.4691 - acc: 0.1023
# Epoch 93/100
# 8000/8000 [==============================] - 1s 155us/step - loss: 14.5587 - acc: 0.0967
# Epoch 94/100
# 8000/8000 [==============================] - 1s 161us/step - loss: 14.5587 - acc: 0.0967
# Epoch 95/100
# 8000/8000 [==============================] - 1s 146us/step - loss: 14.5587 - acc: 0.0967
# Epoch 96/100
# 8000/8000 [==============================] - 1s 161us/step - loss: 14.5587 - acc: 0.0968
# Epoch 97/100
# 8000/8000 [==============================] - 1s 165us/step - loss: 14.5587 - acc: 0.0968
# Epoch 98/100
# 8000/8000 [==============================] - 1s 116us/step - loss: 14.5587 - acc: 0.0968
# Epoch 99/100
# 8000/8000 [==============================] - 1s 144us/step - loss: 14.5587 - acc: 0.0967
# Epoch 100/100
# 8000/8000 [==============================] - 1s 162us/step - loss: 14.5587 - acc: 0.0967
# 2000/2000 [==============================] - 0s 131us/step
# [14.369281875610351, 0.1085]

# %%
loss_and_metrics = model.evaluate(X_test, Y_test)
print(loss_and_metrics)
# Out:
# 2000/2000 [==============================] - 0s 102us/step
# [14.369281875610351, 0.1085]
