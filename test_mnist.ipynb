# %%
import sys,os
import numpy as np, pandas as pd
import dill
from sklearn import datasets
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.optimizers import SGD
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
filename = 'mnist.pickle'
if os.path.exists(filename):
    with open(filename, 'rb') as f:
        mnist = dill.load(f)
else: 
    mnist = datasets.fetch_mldata('MNIST original', data_home='.')
    with open(filename, 'wb') as g:
        dill.dump(mnist, g)

# %%
n = len(mnist.data)
N = 10000 
indices = np.random.permutation(range(n))[:N]
X = mnist.data[indices]
y = mnist.target[indices]
Y = np.eye(10)[y.astype(int)]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=0.8)
# Out:
# /Users/nagoyan/anaconda/envs/p3/lib/python3.5/site-packages/sklearn/model_selection/_split.py:2010: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %% [markdown]
# ### Keras

# %%
n_in = len(X[0])
n_hidden=200
n_out = len(Y[0])
print(n_in, n_hidden, n_out)
# Out:
# 784 200 10

# %%
model = Sequential()

model.add(Dense(n_hidden, input_dim=n_in))
model.add(Activation('sigmoid'))

model.add(Dense(n_hidden))
model.add(Activation('sigmoid'))

model.add(Dense(n_hidden))
model.add(Activation('sigmoid'))

model.add(Dense(n_out))
model.add(Activation('sigmoid'))

model.compile(loss='categorical_crossentropy', optimizer=SGD(lr=0.01), metrics=['accuracy'])

# %%
epochs = 100
batch_size = 100

model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size)
# Out:
# Epoch 1/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.4373 - acc: 0.8913
# Epoch 2/100
# 8000/8000 [==============================] - 1s 78us/step - loss: 0.4128 - acc: 0.8976
# Epoch 3/100
# 8000/8000 [==============================] - 1s 78us/step - loss: 0.3955 - acc: 0.9030
# Epoch 4/100
# 8000/8000 [==============================] - 1s 79us/step - loss: 0.3825 - acc: 0.9054
# Epoch 5/100
# 8000/8000 [==============================] - 1s 81us/step - loss: 0.3717 - acc: 0.9087
# Epoch 6/100
# 8000/8000 [==============================] - 1s 85us/step - loss: 0.3631 - acc: 0.9100
# Epoch 7/100
# 8000/8000 [==============================] - 1s 85us/step - loss: 0.3542 - acc: 0.9138
# Epoch 8/100
# 8000/8000 [==============================] - 1s 92us/step - loss: 0.3453 - acc: 0.9144
# Epoch 9/100
# 8000/8000 [==============================] - 1s 87us/step - loss: 0.3389 - acc: 0.9184
# Epoch 10/100
# 8000/8000 [==============================] - 1s 91us/step - loss: 0.3321 - acc: 0.9174
# Epoch 11/100
# 8000/8000 [==============================] - 1s 95us/step - loss: 0.3254 - acc: 0.9196
# Epoch 12/100
# 8000/8000 [==============================] - 1s 95us/step - loss: 0.3198 - acc: 0.9208
# Epoch 13/100
# 8000/8000 [==============================] - 1s 89us/step - loss: 0.3139 - acc: 0.9248
# Epoch 14/100
# 8000/8000 [==============================] - 1s 97us/step - loss: 0.3090 - acc: 0.9244
# Epoch 15/100
# 8000/8000 [==============================] - 1s 94us/step - loss: 0.3035 - acc: 0.9244
# Epoch 16/100
# 8000/8000 [==============================] - 1s 88us/step - loss: 0.2986 - acc: 0.9273
# Epoch 17/100
# 8000/8000 [==============================] - 1s 87us/step - loss: 0.2946 - acc: 0.9276
# Epoch 18/100
# 8000/8000 [==============================] - 1s 91us/step - loss: 0.2902 - acc: 0.9290
# Epoch 19/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.2860 - acc: 0.9295
# Epoch 20/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.2829 - acc: 0.9300
# Epoch 21/100
# 8000/8000 [==============================] - 1s 98us/step - loss: 0.2794 - acc: 0.9298
# Epoch 22/100
# 8000/8000 [==============================] - 1s 104us/step - loss: 0.2762 - acc: 0.9306
# Epoch 23/100
# 8000/8000 [==============================] - 1s 99us/step - loss: 0.2734 - acc: 0.9309
# Epoch 24/100
# 8000/8000 [==============================] - 1s 97us/step - loss: 0.2705 - acc: 0.9319
# Epoch 25/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.2671 - acc: 0.9324
# Epoch 26/100
# 8000/8000 [==============================] - 1s 105us/step - loss: 0.2642 - acc: 0.9339
# Epoch 27/100
# 8000/8000 [==============================] - 1s 99us/step - loss: 0.2613 - acc: 0.9339
# Epoch 28/100
# 8000/8000 [==============================] - 1s 97us/step - loss: 0.2591 - acc: 0.9349
# Epoch 29/100
# 8000/8000 [==============================] - 1s 97us/step - loss: 0.2565 - acc: 0.9353
# Epoch 30/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0.2540 - acc: 0.9351
# Epoch 31/100
# 8000/8000 [==============================] - 1s 95us/step - loss: 0.2521 - acc: 0.9361
# Epoch 32/100
# 8000/8000 [==============================] - 1s 94us/step - loss: 0.2494 - acc: 0.9377
# Epoch 33/100
# 8000/8000 [==============================] - 1s 100us/step - loss: 0.2472 - acc: 0.9370
# Epoch 34/100
# 8000/8000 [==============================] - 1s 86us/step - loss: 0.2456 - acc: 0.9376
# Epoch 35/100
# 8000/8000 [==============================] - 1s 95us/step - loss: 0.2436 - acc: 0.9385
# Epoch 36/100
# 8000/8000 [==============================] - 1s 99us/step - loss: 0.2416 - acc: 0.9389
# Epoch 37/100
# 8000/8000 [==============================] - 1s 97us/step - loss: 0.2393 - acc: 0.9381
# Epoch 38/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.2382 - acc: 0.9394
# Epoch 39/100
# 8000/8000 [==============================] - 1s 99us/step - loss: 0.2363 - acc: 0.9393
# Epoch 40/100
# 8000/8000 [==============================] - 1s 99us/step - loss: 0.2346 - acc: 0.9390
# Epoch 41/100
# 8000/8000 [==============================] - 1s 98us/step - loss: 0.2331 - acc: 0.9395
# Epoch 42/100
# 8000/8000 [==============================] - 1s 101us/step - loss: 0.2313 - acc: 0.9393
# Epoch 43/100
# 8000/8000 [==============================] - 1s 97us/step - loss: 0.2299 - acc: 0.9403
# Epoch 44/100
# 8000/8000 [==============================] - 1s 88us/step - loss: 0.2285 - acc: 0.9396
# Epoch 45/100
# 8000/8000 [==============================] - 1s 102us/step - loss: 0